# %% [markdown]
# # **About Dataset**
# ## **Data Description**
#
# The dataset is from an ongoing cardiovascular study on residents of the town of Framingham, Massachusetts. The classification goal is to predict whether the patient has 10-year risk of future coronary heart disease (CHD).The dataset provides the patients’ information. It includes over 4,000 records and 15 attributes. Each attribute is a potential risk factor. There are both demographic, behavioral and medical risk factors.
#
# Features:
# ```
# 1. male | male or female | binary: “1”, means “Yes”, “0” means “No”
# 2. Age | | Age of the patient | Age of the patient |
# 3. Cigs Per Day | the number of cigarettes that the person smoked on average in one day |
# 4.  BP Meds | whether or not the patient was on blood pressure medication |
# 5. Prevalent Stroke | whether or not the patient had previously had a stroke |
# 6. Prevalent Hyp | whether or not the patient was hypertensive |
# 7. Diabetes | whether or not the patient had diabetes |
# 8. Tot Chol | total cholesterol level |
# 9. Sys BP | systolic blood pressure |
# 10. Dia BP | diastolic blood pressure |
# 11. BMI |  Body Mass Index  |
# 12. Heart Rate |  heart rate |
# 13. Glucose | glucose level |
# 14. TenYearCHD | 10 year risk of coronary heart disease CHD (binary: “1”, means “Yes”, “0” means “No”) - TARGET
#
# ```
#
# ---
#
#
# All of the dataset values were collected at the moment of medical examination.
#
#
#
# ---

# %%
# from google.colab import drive
# drive.mount('/content/drive')
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df_master=pd.read_csv("./framingham_heart_disease.csv")
df=df_master.copy()
df_arpita=df_master.copy()
df_moumita=df_master.copy()
df_snehasish=df_master.copy()
df_drippta=df_master.copy()
df_drippta
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %% [markdown]
# ## EDA Subhodip
#
# ```Satrt```

# %%
df.shape
# Out:
# (4240, 16)
# (4240, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4240 entries, 0 to 4239
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4240 non-null   int64
#  1   age              4240 non-null   int64
#  2   education        4135 non-null   float64
#  3   currentSmoker    4240 non-null   int64
#  4   cigsPerDay       4211 non-null   float64
#  5   BPMeds           4187 non-null   float64
#  6   prevalentStroke  4240 non-null   int64
#  7   prevalentHyp     4240 non-null   int64
#  8   diabetes         4240 non-null   int64
#  9   totChol          4190 non-null   float64
#  10  sysBP            4240 non-null   float64
#  11  diaBP            4240 non-null   float64
#  12  BMI              4221 non-null   float64
#  13  heartRate        4239 non-null   float64
#  14  glucose          3852 non-null   float64
#  15  TenYearCHD       4240 non-null   int64
# dtypes: float64(9), int64(7)
# ...

# %%
df.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4240.000000  4240.000000  4135.000000    4240.000000  4211.000000
# mean      0.429245    49.580189     1.979444       0.494104     9.005937
# std       0.495027     8.572942     1.019791       0.500024    11.922462
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4187.000000      4240.000000   4240.000000  4240.000000  4190.000000
# mean      0.029615         0.005896      0.310613     0.025708   236.699523
# std       0.169544         0.076569      0.462799     0.158280    44.591284
# ...

# %%
df.isna().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
df["education"].corr(df["TenYearCHD"])
# Out:
# -0.05424846659632095
# -0.05424846659632095

# %%
plt.figure(figsize=(15,10))
sns.set_context('notebook',font_scale = 0.9)
sns.heatmap(df.corr(),cmap="YlGnBu",linewidths=0.,annot=True)
plt.tight_layout()

# %%
# plt.figure(figsize=(6,6))
sns.heatmap(df.isna())
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,5))
df.drop('TenYearCHD', axis=1,inplace=False).corrwith(df.TenYearCHD).plot(kind='bar',grid=True)
plt.tight_layout()

# %%
sns.countplot(x=df.male)
# Out:
# <AxesSubplot:xlabel='male', ylabel='count'>

# %%
sns.countplot(x=df.male,hue=df.TenYearCHD)
# Out:
# <AxesSubplot:xlabel='male', ylabel='count'>

# %%
totMale=df[df["male"]==0].shape[0]
maleCHD=df[(df["male"]==0) & (df["TenYearCHD"]==1)].shape[0]
maleCHDPercent=(maleCHD/totMale)*100
print("Percentage of Female having heart disease",maleCHDPercent)
df[(df["male"]==0) & (df["TenYearCHD"]==1)]
# Out:
# Percentage of Female having heart disease 12.43801652892562
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 3        0   61        3.0              1        30.0     0.0
# 6        0   63        1.0              0         0.0     0.0
# 15       0   38        2.0              1        20.0     0.0
# 17       0   46        2.0              1        20.0     0.0
# 28       0   61        3.0              0         0.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4188     0   44        3.0              0         0.0     0.0
# 4193     0   63        1.0              0         0.0     0.0
# 4199     0   61        1.0              0         0.0     0.0
# 4207     0   61        4.0              0         0.0     0.0
# 4214     0   56        3.0              1         5.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 3                   0             1         0    225.0  150.0   95.0  28.58
# ...

# %%
tot=df[df["male"]==1].shape[0]
CHD=df[(df["male"]==1) & (df["TenYearCHD"]==1)].shape[0]
CHDPercent=(maleCHD/totMale)*100
print("Percentage of male having heart disease",maleCHDPercent)
df[(df["male"]==1) & (df["TenYearCHD"]==1)]
# Out:
# Percentage of male having heart disease 12.43801652892562
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 25       1   47        4.0              1        20.0     0.0
# 33       1   61        NaN              1         5.0     0.0
# 64       1   57        1.0              0         0.0     0.0
# 81       1   39        2.0              0         0.0     0.0
# 94       1   60        4.0              1        30.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4221     1   50        1.0              0         0.0     0.0
# 4223     1   56        4.0              0         0.0     1.0
# 4226     1   58        1.0              0         0.0     0.0
# 4232     1   68        1.0              0         0.0     0.0
# 4233     1   50        1.0              1         1.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 25                  0             0         0    294.0  102.0   68.0  24.18
# ...

# %%
sns.countplot(x=df.education)
# Out:
# <AxesSubplot:xlabel='education', ylabel='count'>

# %%
df.corr().education
# Out:
# male               0.017415
# age               -0.166356
# education          1.000000
# currentSmoker      0.018528
# cigsPerDay         0.008323
# BPMeds            -0.010898
# prevalentStroke   -0.035142
# prevalentHyp      -0.081726
# diabetes          -0.038749
# totChol           -0.023613
# sysBP             -0.129496
# diaBP             -0.061919
# BMI               -0.137747
# heartRate         -0.054182
# glucose           -0.035843
# TenYearCHD        -0.054248
# Name: education, dtype: float64

# %%
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=df.age,palette='gist_earth')
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=df.age,hue=df.TenYearCHD)
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %% [markdown]
# ```End```

# %% [markdown]
# ## EDA Arpita
#
# ```Start```
#
# use ```ctrl+M``` then ```B``` to insert new cell in your area.

# %%
df_arpita
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %% [markdown]
# ```end```

# %%
df.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %%
df.shape
# Out:
# (4240, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4240 entries, 0 to 4239
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4240 non-null   int64
#  1   age              4240 non-null   int64
#  2   education        4135 non-null   float64
#  3   currentSmoker    4240 non-null   int64
#  4   cigsPerDay       4211 non-null   float64
#  5   BPMeds           4187 non-null   float64
#  6   prevalentStroke  4240 non-null   int64
#  7   prevalentHyp     4240 non-null   int64
#  8   diabetes         4240 non-null   int64
#  9   totChol          4190 non-null   float64
#  10  sysBP            4240 non-null   float64
#  11  diaBP            4240 non-null   float64
#  12  BMI              4221 non-null   float64
#  13  heartRate        4239 non-null   float64
#  14  glucose          3852 non-null   float64
#  15  TenYearCHD       4240 non-null   int64
# dtypes: float64(9), int64(7)
# ...

# %%
df.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
df.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4240.000000  4240.000000  4135.000000    4240.000000  4211.000000
# mean      0.429245    49.580189     1.979444       0.494104     9.005937
# std       0.495027     8.572942     1.019791       0.500024    11.922462
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4187.000000      4240.000000   4240.000000  4240.000000  4190.000000
# mean      0.029615         0.005896      0.310613     0.025708   236.699523
# std       0.169544         0.076569      0.462799     0.158280    44.591284
# ...

# %%
df.tail()
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 4235                0             0         0    248.0  131.0   72.0  22.00
# 4236                0             0         0    210.0  126.5   87.0  19.16
# 4237                0             0         0    269.0  133.5   83.0  21.47
# 4238                0             1         0    185.0  141.0   98.0  25.60
# 4239                0             0         0    196.0  133.0   86.0  20.91
#
#       heartRate  glucose  TenYearCHD
# 4235       84.0     86.0           0
# 4236       86.0      NaN           0
# ...

# %%
df['male'].value_counts()
# Out:
# 0    2420
# 1    1820
# Name: male, dtype: int64

# %%
sns.countplot(x=df.glucose[0:20],hue=df.male)
# Out:
# <AxesSubplot:xlabel='glucose', ylabel='count'>

# %%
df.drop(columns=['education','currentSmoker','heartRate'],inplace=True)

# %%
df
# Out:
#       male  age  cigsPerDay  BPMeds  prevalentStroke  prevalentHyp  diabetes  \
# 0        1   39         0.0     0.0                0             0         0
# 1        0   46         0.0     0.0                0             0         0
# 2        1   48        20.0     0.0                0             0         0
# 3        0   61        30.0     0.0                0             1         0
# 4        0   46        23.0     0.0                0             0         0
# ...    ...  ...         ...     ...              ...           ...       ...
# 4235     0   48        20.0     NaN                0             0         0
# 4236     0   44        15.0     0.0                0             0         0
# 4237     0   52         0.0     0.0                0             0         0
# 4238     1   40         0.0     0.0                0             1         0
# 4239     0   39        30.0     0.0                0             0         0
#
# ...

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=df.cigsPerDay,hue=df.TenYearCHD)
# Out:
# <AxesSubplot:xlabel='cigsPerDay', ylabel='count'>

# %%
plt.figure(figsize=(20,10))
sns.set_style('whitegrid')
sns.countplot(x = df.age ,hue=df.TenYearCHD, palette = 'inferno')
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
sns.countplot(x=df.diabetes,hue=df.male)
# Out:
# <AxesSubplot:xlabel='male', ylabel='count'>

# %%
df[df.diabetes==1].diabetes.count()
# Out:
# 109

# %%
plt.figure(figsize=(2.5,5))
sns.boxplot(x= df.TenYearCHD, y = df.totChol[0:100], palette='magma')
# Out:
# <AxesSubplot:xlabel='TenYearCHD', ylabel='totChol'>

# %%
plt.figure(figsize=(20,10))
sns.set_style('whitegrid')
sns.countplot(x = df.diabetes ,hue=df.TenYearCHD, palette = 'inferno')
# Out:
# <AxesSubplot:xlabel='diabetes', ylabel='count'>

# %% [markdown]
# ## EDA Moumita
#
# ```Start```
#
# use ```ctrl+M``` then ```B``` to insert new cell in your area.

# %%
df_moumita

# %%
sns.countplot(x=df.glucose[:20],hue=df.male)
# Out:
# <AxesSubplot:xlabel='glucose', ylabel='count'>

# %% [markdown]
# ```end```

# %% [markdown]
# ## EDA Snehasish
#
# ```Start```
#
# use ```ctrl+M``` then ```B``` to insert new cell in your area.

# %% [markdown]
# ```end```

# %%
df.head()

# %% [markdown]
# ## EDA Drippta
#
# ```Start```
#
# use ```ctrl+M``` then ```B``` to insert new cell in your area.

# %%
df_drippta
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df_drippta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4240 entries, 0 to 4239
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4240 non-null   int64
#  1   age              4240 non-null   int64
#  2   education        4135 non-null   float64
#  3   currentSmoker    4240 non-null   int64
#  4   cigsPerDay       4211 non-null   float64
#  5   BPMeds           4187 non-null   float64
#  6   prevalentStroke  4240 non-null   int64
#  7   prevalentHyp     4240 non-null   int64
#  8   diabetes         4240 non-null   int64
#  9   totChol          4190 non-null   float64
#  10  sysBP            4240 non-null   float64
#  11  diaBP            4240 non-null   float64
#  12  BMI              4221 non-null   float64
#  13  heartRate        4239 non-null   float64
#  14  glucose          3852 non-null   float64
#  15  TenYearCHD       4240 non-null   int64
# dtypes: float64(9), int64(7)
# ...

# %%
df_drippta.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4240.000000  4240.000000  4135.000000    4240.000000  4211.000000
# mean      0.429245    49.580189     1.979444       0.494104     9.005937
# std       0.495027     8.572942     1.019791       0.500024    11.922462
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4187.000000      4240.000000   4240.000000  4240.000000  4190.000000
# mean      0.029615         0.005896      0.310613     0.025708   236.699523
# std       0.169544         0.076569      0.462799     0.158280    44.591284
# ...

# %%
df_drippta.corr()
# Out:
#                      male       age  education  currentSmoker  cigsPerDay  \
# male             1.000000 -0.029014   0.017415       0.197026    0.317143
# age             -0.029014  1.000000  -0.166356      -0.213662   -0.192959
# education        0.017415 -0.166356   1.000000       0.018528    0.008323
# currentSmoker    0.197026 -0.213662   0.018528       1.000000    0.769774
# cigsPerDay       0.317143 -0.192959   0.008323       0.769774    1.000000
# BPMeds          -0.052504  0.123052  -0.010898      -0.048927   -0.046155
# prevalentStroke -0.004550  0.057679  -0.035142      -0.032980   -0.032711
# prevalentHyp     0.005853  0.306799  -0.081726      -0.103710   -0.066645
# diabetes         0.015693  0.101314  -0.038749      -0.044285   -0.037089
# totChol         -0.070413  0.262554  -0.023613      -0.046488   -0.026479
# sysBP           -0.035879  0.394053  -0.129496      -0.130281   -0.088797
# diaBP            0.058199  0.205586  -0.061919      -0.107933   -0.056715
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df_drippta.corr(),cmap="magma", annot = True, annot_kws = {"size":10})
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,7))
sns.set_style('whitegrid')
sns.countplot(x = 'TenYearCHD', data = df_drippta, palette = 'winter')
# Out:
# <AxesSubplot:xlabel='TenYearCHD', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x = 'TenYearCHD', hue = 'male', data = df_drippta, palette = 'winter')
# Out:
# <AxesSubplot:xlabel='TenYearCHD', ylabel='count'>

# %%
df_drippta.isnull()
# Out:
#        male    age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0     False  False      False          False       False   False
# 1     False  False      False          False       False   False
# 2     False  False      False          False       False   False
# 3     False  False      False          False       False   False
# 4     False  False      False          False       False   False
# ...     ...    ...        ...            ...         ...     ...
# 4235  False  False      False          False       False    True
# 4236  False  False      False          False       False   False
# 4237  False  False      False          False       False   False
# 4238  False  False      False          False       False   False
# 4239  False  False      False          False       False   False
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0               False         False     False    False  False  False  False
# ...

# %%
sns.heatmap(df_drippta.isnull(), yticklabels = False, cbar = True, cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,10))
sns.barplot(x= 'age', y = 'cigsPerDay', data = df_drippta, palette = 'winter')
# Out:
# <AxesSubplot:xlabel='age', ylabel='cigsPerDay'>

# %%
plt.figure(figsize=(15,10))
sns.barplot(x= 'age', y = 'diabetes', data = df_drippta, palette = 'winter')
# Out:
# <AxesSubplot:xlabel='age', ylabel='diabetes'>

# %% [markdown]
# ```end```
